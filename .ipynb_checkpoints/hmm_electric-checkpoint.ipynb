# %%
import numpy as np
import pandas as pd
import os       
import math
import random
import pickle as pkl
from tqdm import tqdm
import scipy.stats as stats
import seaborn as sns
from phmm import PHMM
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class HMM:    
    def __init__(self, K, transition_matrix, observation_mean, observation_std, initial_state): 
        self.K = int(K)
        self.A = transition_matrix  
        self.mean = observation_mean
        self.std = observation_std
        self.pi = initial_state
    
    def forward(self, X):
        self.alpha = np.zeros((len(X), self.K))
        self.C = np.zeros(len(X))
        for k in range(self.K):
            self.alpha[0][k] = self.pi[k] * self.prob(X[0], self.mean[k], self.std[k])
        self.C[0] = sum(self.alpha[0])
        self.alpha[0] /= self.C[0]
        for t in range(1, len(X)):
            for k in range(self.K):
                self.alpha[t][k] = sum([self.alpha[t-1][k0] * self.A[k0][k] 
                                        * self.prob(X[t], self.mean[k], self.std[k]) for k0 in range(self.K)])
            self.C[t] = sum(self.alpha[t])
            self.alpha[t] /= self.C[t]
    
    def backward(self, X):
        self.beta = np.ones((len(X), self.K))
        for t in range(len(X)-2, -1, -1):
            for k in range(self.K):
                self.beta[t][k] = sum([self.beta[t+1][k0] * self.A[k][k0]
                                       * self.prob(X[t+1], self.mean[k0], self.std[k0]) for k0 in range(self.K)])
            self.beta[t] /= self.C[t+1]
    
    def EM(self, X, num_iter=100):
        for i in tqdm(range(num_iter)):
            self.forward(X)
            self.backward(X)
            gamma = self.alpha * self.beta
            xi = np.zeros((len(X), self.K, self.K))
            for t in range(len(X)-1):
                for j in range(self.K):
                    for k in range(self.K):
                        xi[t][j][k] = ((self.alpha[t][j] * self.A[j][k] * self.prob(X[t+1],self.mean[k],self.std[k])
                                       * self.beta[t+1][k]) / self.C[t+1])
            self.pi = [gamma[0][k]/sum(gamma[0]) for k in range(self.K)]
            
            for j in range(self.K):
                for k in range(self.K):
                    self.A[j][k] = sum(xi[:,j,k]) / sum([sum(xi[:,j,l]) for l in range(self.K)])
            
            for k in range(self.K):
                self.mean[k] = sum(X*gamma[:,k]) / sum(gamma[:,k])
                self.std[k] = np.sqrt(sum(X*X*gamma[:,k]) / sum(gamma[:,k]) - self.mean[k]**2)
                
    def prob(self, x, mean, std):
        return np.exp(-0.5*(mean-x)**2/std**2)/np.sqrt(2*np.pi*std**2)
    
    def best_states_seq(self, x):
        z = []
        V = np.zeros((len(x), self.K) ) - 10**5
        best_states = np.zeros((len(x), self.K))

        for n in range(len(x)):
            for j in range(self.K):
                if n == 0:
                    V[n,j] = np.log(self.prob(x[n], self.mean[j], self.std[j])) + np.log(self.pi[j]+1e-5)
                    best_states[n,j] = -1
                else:
                    for i in range(self.K):
                        prob = np.log(self.prob(x[n], self.mean[j], self.std[j])) + V[n-1, i] + np.log(self.A[i, j])
                        if prob > V[n,j]:
                            V[n,j] = prob
                            best_states[n,j] = i
          
        index = int(np.where(V[-1,:]==max(V[-1,:]))[0])
        z.append(index)
        for n in range(1, len(x)):
            index = int(best_states[-n, index])
            z.append(index)
        return z[::-1]
    
    def sample_by_states(self, Z, seed=None):
        if seed:
            np.random.seed(seed)
        obs = []
        for z in Z:
            obs.append(np.random.normal(self.mean[z], self.std[z]))
        return obs

# %%
def runHMM(train, valid, K, num_iter=1000, seed=1):
    x_train = np.array(train).reshape(-1)
    x_valid = np.array(valid).reshape(-1)
    A = np.random.randint(1,10,size = [K,K])
    transition_matrix = np.array([a/sum(a) for a in A])
    observation_mean = np.ones(K)*np.mean(x_train)
    observation_std = np.ones(K)*np.std(x_train)
    initial_states = A[1]/sum(A[1])
    
    hmm = HMM(K, transition_matrix, observation_mean, observation_std, initial_states)
    
    hmm.EM(x_train, num_iter)
    
    pred_hidden = hmm.best_states_seq(x_valid)
    pred_obs = hmm.sample_by_states(pred_hidden, seed=seed)
    bias = np.mean(pred_obs - x_valid)
    smape = np.mean(2*np.abs(pred_obs-x_valid)/(np.abs(pred_obs)+np.abs(x_valid)))
    rmse = np.sqrt(np.mean((pred_obs-x_valid)**2))
    
    return ([hmm, pred_hidden, pred_obs], [smape, bias, rmse])

# %%
df = pd.read_csv('data/Electric_Production.csv')
df.rename(columns = {"DATE":"Date","IPG2211A2N":"Monthly Electricity Production"},inplace = True)
df["Date"] = pd.to_datetime(df["Date"],infer_datetime_format = True)
df = df.set_index(["Date"])

# %%
plt.figure(figsize = (12,6))
plt.title("Monthly Electricity Production")
plt.xlabel("Date")
plt.plot(df, label='Electric production')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.distplot(df, bins=20, label='Monthly Electricity Production')
plt.title('Electricity Production Density Distribution')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (15,10))
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(df, freq=90)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(df,label = "Original")
plt.legend(loc = "best")
plt.subplot(412)
plt.plot(trend,label = "Trend")
plt.legend(loc = "best")
plt.subplot(413)
plt.plot(seasonal ,label = "seasonal")
plt.legend(loc = "best")
plt.subplot(414)
plt.plot(residual,label = "Residuals")
plt.legend(loc = "best")
plt.tight_layout()
plt.show()

# %%
train = df[:int(0.8*len(df))]
valid = df[int(0.8*len(df)):int(0.9*len(df))]
test = df[int(0.9*len(df)):]

# %%
K_range = [2,4,6,8,10,12]
table = []
best_model = 0
best_mape = 1
for K in K_range:
    print('Training for K = {}'.format(K))
    result = runHMM(train, valid, K, 500)
    table.append(result[1])
    if result[1][0] < best_mape:
        best_model = result[0]
# Out:
#   1%|          | 3/500 [00:00<00:20, 23.74it/s]
# Training for K = 2
# 100%|██████████| 500/500 [00:15<00:00, 32.70it/s]
#   0%|          | 1/500 [00:00<00:54,  9.13it/s]
# Training for K = 4
# 100%|██████████| 500/500 [00:52<00:00,  9.50it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Training for K = 6
# 100%|██████████| 500/500 [01:58<00:00,  4.23it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Training for K = 8
# 100%|██████████| 500/500 [03:27<00:00,  2.41it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Training for K = 10
# 100%|██████████| 500/500 [05:42<00:00,  1.46it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# Training for K = 12
# 100%|██████████| 500/500 [08:29<00:00,  1.02s/it]

# %%
result = runHMM(df[:300], df[300:], 10)
# Out:
# 100%|██████████| 1000/1000 [10:35<00:00,  1.57it/s]

# %%
pd.DataFrame(table, columns=['SMAPE', 'BIAS', 'RMSE'], index=['K=2', 'K=4', 'K=6', 'K=8', 'K=10', 'K=12'])
# Out:
#          SMAPE      BIAS       RMSE
# K=2   0.136545 -9.320877  16.019296
# K=4   0.116102 -5.187142  13.618291
# K=6   0.066810 -3.033333   8.632619
# K=8   0.111855 -3.821543  13.088364
# K=10  0.047132 -2.394177   6.032034
# K=12  0.055605 -2.693594   7.162300

# %%
valid['pred'] = best_model[2]
hmm = best_model[0]
Z = best_model[1]
plt.figure(figsize=(18,12))
plt.subplot(2,1,1)
plt.plot(train, label = 'train')
plt.plot(valid['Monthly Electricity Production'], label = 'validation')
plt.plot(valid.pred, label='prediction')
plt.legend()
plt.title('Electricity Production')

def plot_pdf(mean, std, frac, label):
    x = np.linspace(mean - 4*std, mean + 4*std, 100)
    plt.plot(x, frac*stats.norm.pdf(x, mean, std), label=label)

plt.subplot(2,1,2)
for k in range(10):
    plot_pdf(hmm.mean[k], hmm.std[k], Z.count(k)/len(test), 'state {}'.format(k))
plt.legend()
plt.title('Distribution of hidden states')
plt.show()

# %%
best_model, _ = runHMM(pd.concat([train,valid]), test, 10, num_iter=500)
# Out:
# 100%|██████████| 500/500 [07:37<00:00,  1.09it/s]

# %%
test['hmm_pred'] = best_model[2]
test['arima_pred'] = pkl.load(open("data/elec_pred_list.p", "rb"))
test['lstm_pred'] = np.load('data/lstm_electric.npy')

plt.figure(figsize=(15,6))
plt.plot(test['Monthly Electricity Production'], linewidth=2.5, color='black',label = 'test data')
plt.plot(test.arima_pred, '--', linewidth=2, label='ARIMA prediction')
plt.plot(test.hmm_pred, label='HMM prediction')
plt.plot(test.lstm_pred, 'o', label='LSTM prediction')
plt.legend()
plt.title('Electricity Production')
plt.show()

# %%
actual = test['Monthly Electricity Production']
smape = np.mean(200*np.abs(test.arima_pred-actual)/(np.abs(test.arima_pred)+np.abs(actual)))
rmse = np.sqrt(np.mean((test.arima_pred-actual)**2))
print('ARIMA: SMAPE = {:.2f}%, RMSE = {:.2f}'.format(smape, rmse))

smape = np.mean(200*np.abs(test.hmm_pred-actual)/(np.abs(test.hmm_pred)+np.abs(actual)))
rmse = np.sqrt(np.mean((test.hmm_pred-actual)**2))
print('HMM:   SMAPE = {:.2f}%, RMSE = {:.2f}'.format(smape, rmse))

smape = np.mean(200*np.abs(test.lstm_pred-actual)/(np.abs(test.lstm_pred)+np.abs(actual)))
rmse = np.sqrt(np.mean((test.lstm_pred-actual)**2))
print('LSTM:  SMAPE = {:.2f}%, RMSE = {:.2f}'.format(smape, rmse))
# Out:
# ARIMA: SMAPE = 2.48%, RMSE = 3.79
# HMM:   SMAPE = 5.22%, RMSE = 7.39
# LSTM:  SMAPE = 11.74%, RMSE = 14.40
